# %% [markdown]
# # Pandas

# %% [markdown]
# * Pandas stands for Panel data.
# * It is a Python library and it has been developed over Numpy
# * Pandas is used for data manipulation as we use excel
# * In pandas we work upon two types of objects
# * Series
# * Dataframe

# %%
import pandas as pd

# %%
lst=[10,20,30,40,50,60,70,80]

# %%
num=pd.Series(lst) # lst
print(num,type(num))
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# 6    70
# 7    80
# dtype: int64 <class 'pandas.core.series.Series'>

# %% [markdown]
# # Data Frame

# %% [markdown]
# It is like a 2-D array structure
# * It can be considered as a table from an excel sheet

# %%
names=['Akansha','Gopal','Suresh','Divya','Nikhil']
codes=[101,102,103,104,105]
city=['Pune','Chennai','Delhi','Dehradun','Madurai']

# %%
lst=[names,codes,city]
lst
# Out:
# [['Akansha', 'Gopal', 'Suresh', 'Divya', 'Nikhil'],
#  [101, 102, 103, 104, 105],
#  ['Pune', 'Chennai', 'Delhi', 'Dehradun', 'Madurai']]

# %%
df=pd.DataFrame(lst).T

# %%
df
# Out:
#          0    1         2
# 0  Akansha  101      Pune
# 1    Gopal  102   Chennai
# 2   Suresh  103     Delhi
# 3    Divya  104  Dehradun
# 4   Nikhil  105   Madurai

# %%
df.columns=['Name','ID','City']

# %%
df
# Out:
#       Name   ID      City
# 0  Akansha  101      Pune
# 1    Gopal  102   Chennai
# 2   Suresh  103     Delhi
# 3    Divya  104  Dehradun
# 4   Nikhil  105   Madurai

# %%
df=pd.read_csv('train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Attributes on a dataframe

# %%
#size
#dtypes
#shape
#columns
#index
#values
#ndim
#len

# %% [markdown]
# # Size

# %% [markdown]
# * The number of total values in a dataframe

# %%
df.size
# Out:
# 10692

# %% [markdown]
# # shape

# %% [markdown]
# * The number of rows and columns

# %%
df.shape # 891 rows and 12 columns
# Out:
# (891, 12)

# %% [markdown]
# # dtypes

# %% [markdown]
# * It returns a series that contains the types of all the columns of a dataframe

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# # columns

# %% [markdown]
# * It returns the columns index that contains the names of the columns

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.values
# Out:
# array([[1, 0, 3, ..., 7.25, nan, 'S'],
#        [2, 1, 1, ..., 71.2833, 'C85', 'C'],
#        [3, 1, 3, ..., 7.925, nan, 'S'],
#        ...,
#        [889, 0, 3, ..., 23.45, nan, 'S'],
#        [890, 1, 1, ..., 30.0, 'C148', 'C'],
#        [891, 0, 3, ..., 7.75, nan, 'Q']], dtype=object)

# %% [markdown]
# # len(df)

# %% [markdown]
# * It returns the number of rows in the a dataframe

# %%
len(df)
# Out:
# 891

# %% [markdown]
# # Functions on Dataframe

# %% [markdown]
# # Head()

# %% [markdown]
# * It returns first 5 rows of the dataframe

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.head(80)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# ..          ...       ...     ...
# 75           76         0       3
# 76           77         0       3
# 77           78         0       3
# 78           79         1       2
# 79           80         1       3
#
#                                                  Name     Sex    Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.00      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.00      1
# 2                              Heikkinen, Miss. Laina  female  26.00      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.00      1
# 4                            Allen, Mr. William Henry    male  35.00      0
# ..                                                ...     ...    ...    ...
# ...

# %% [markdown]
# # Tail()

# %% [markdown]
# * It returns the last 5 rows of the dataframe

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.tail(50)
# Out:
#      PassengerId  Survived  Pclass  \
# 841          842         0       2
# 842          843         1       1
# 843          844         0       3
# 844          845         0       3
# 845          846         0       3
# 846          847         0       3
# 847          848         0       3
# 848          849         0       2
# 849          850         1       1
# 850          851         0       3
# 851          852         0       3
# 852          853         0       3
# 853          854         1       1
# 854          855         0       2
# 855          856         1       3
# 856          857         1       1
# 857          858         1       1
# 858          859         1       3
# 859          860         0       3
# 860          861         0       3
# 861          862         0       2
# 862          863         1       1
# 863          864         0       3
# 864          865         0       2
# 865          866         1       2
# ...

# %% [markdown]
# # info()

# %% [markdown]
# * It returns a sereis that contains some basic infromation about the dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
891-204 #cabin
# Out:
# 687

# %%
891-714 #aged
# Out:
# 177

# %% [markdown]
# # describe

# %% [markdown]
# * It returns the 5-point statistical summary
# * mean,median,std,min,max
# * It only considers the numerical columns

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # nunique

# %% [markdown]
# * It returns the number of unique values column wise in a dataframe

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %% [markdown]
# # unique()

# %% [markdown]
# * It returns an array that contains the unique values in a column

# %%
df.Survived.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
df['Survived'].unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# # value_counts

# %% [markdown]
# * It returns the count of unique values in a particular column

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
577+314
# Out:
# 891

# %%
df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
# Null values

# %%
# isna()
#isnull()
# -These functions check the missing values and returns a boolean dataframe

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Dropping the missing values

# %% [markdown]
# # df.dropna()
# * It drops all the rows that have atleast 1 missing values
# * It returns a new dataframe after dropping the rows

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#df.drop('Cabin',axis=1)

# %%
df.drop('Cabin',axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop('Cabin',axis=1,inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
df.drop(['PassengerId','Ticket'],axis=1,inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch     Fare Embarked
# ...

# %% [markdown]
# # How to rename a column

# %%
df.rename({'Sex':'Gender','SibSp':'Siblings','Parch':'Parents'},axis=1,inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#      Gender   Age  Siblings  Parents     Fare Embarked
# ...

# %% [markdown]
# # Data Filteration

# %%
# Extract the data of male passengers only

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#      Gender   Age  Siblings  Parents     Fare Embarked
# ...

# %%
df[df.Gender=='male']
# Out:
#      Survived  Pclass                            Name Gender   Age  Siblings  \
# 0           0       3         Braund, Mr. Owen Harris   male  22.0         1
# 4           0       3        Allen, Mr. William Henry   male  35.0         0
# 5           0       3                Moran, Mr. James   male   NaN         0
# 6           0       1         McCarthy, Mr. Timothy J   male  54.0         0
# 7           0       3  Palsson, Master. Gosta Leonard   male   2.0         3
# ..        ...     ...                             ...    ...   ...       ...
# 883         0       2   Banfield, Mr. Frederick James   male  28.0         0
# 884         0       3          Sutehall, Mr. Henry Jr   male  25.0         0
# 886         0       2           Montvila, Rev. Juozas   male  27.0         0
# 889         1       1           Behr, Mr. Karl Howell   male  26.0         0
# 890         0       3             Dooley, Mr. Patrick   male  32.0         0
#
#      Parents     Fare Embarked
# ...

# %%
# How many male passengers survived
df[(df.Gender=='male') & (df.Survived==1)].count()
# Out:
# Survived    109
# Pclass      109
# Name        109
# Gender      109
# Age          93
# Siblings    109
# Parents     109
# Fare        109
# Embarked    109
# dtype: int64

# %% [markdown]
# # Filling the missing values

# %%
df.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Gender        0
# Age         177
# Siblings      0
# Parents       0
# Fare          0
# Embarked      2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Gender    891 non-null    object
#  4   Age       714 non-null    float64
#  5   Siblings  891 non-null    int64
#  6   Parents   891 non-null    int64
#  7   Fare      891 non-null    float64
#  8   Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
# If the column is numeric continous then we generally fill the missing values by mean or medain.
# If the column is categorical then we generally fill the missing value by mode value

# %% [markdown]
# # Age

# %%
df.Age.isna().sum()
# Out:
# 177

# %%
mean=df.Age.mean()
mean
# Out:
# 29.69911764705882

# %%
median=df.Age.median()
median
# Out:
# 28.0

# %%
# df.Age=df.Age.fillna(mean)

# %%
df.Age.fillna(mean)
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
df.Age.isnull().sum()
# Out:
# 177

# %%
df.Age.fillna(mean,inplace=True)

# %%
df.Age.isnull().sum()
# Out:
# 0

# %%
# [1,2,1,1,3,4,2,5] mode=1
# ['Ban','chennai','Hyd','Ban'] mode='Ban'

# %%
df.Embarked
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
# Mode =The value the highest frequency

# %%
df.Embarked.value_counts(dropna=False)
# Out:
# S      644
# C      168
# Q       77
# NaN      2
# Name: Embarked, dtype: int64

# %%
df.Embarked.mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
df.Embarked.isnull().sum()
# Out:
# 2

# %%
mode=df.Embarked.mode()[0]
mode
# Out:
# 'S'

# %%
df.Embarked.fillna(mode,inplace=True)

# %%
df.Embarked.isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Gender      0
# Age         0
# Siblings    0
# Parents     0
# Fare        0
# Embarked    0
# dtype: int64

# %% [markdown]
# # Group by

# %% [markdown]
# * It is used to perform bivariate and multivariate anlaysis

# %%
# How many males amd females survived or died

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#    Gender   Age  Siblings  Parents     Fare Embarked
# 0    male  22.0         1        0   7.2500        S
# 1  female  38.0         1        0  71.2833        C
# 2  female  26.0         0        0   7.9250        S
# 3  female  35.0         1        0  53.1000        S
# 4    male  35.0         0        0   8.0500        S

# %%
# Gender-catgeorical
# survived- categorical
# operation - value_count

# %%
# df.groupby('col name').col_name.function()
# - It returns a Series object

# %%
df.groupby('Gender').Survived.value_counts()
# Out:
# Gender  Survived
# female  1           233
#         0            81
# male    0           468
#         1           109
# Name: Survived, dtype: int64
